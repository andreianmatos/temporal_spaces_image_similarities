# %%
from image_similarity_package import image_similarity

most_similar_image_path, most_similar_image, query_image, max_similarity = image_similarity.find_most_similar_image(
    'current_person.png', 'people/')
print(f"Max Similarity: {max_similarity}")
image_similarity.plot_images(query_image, most_similar_image, 'current person', most_similar_image_path)
# Out:
# Comparing images:
# (100/100)
# Comparison finished.
# Max Similarity: 0.7713119983673096
